# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagenerator = ImageDataGenerator(rescale = 1./255,
                                            shear_range = 0.2,
                                            zoom_range = 0.2,
                                            horizontal_flip = True)

# %%
training_set = train_datagenerator.flow_from_directory('dataset/training_set',
                                                       target_size = (64, 64),
                                                       batch_size = 32,
                                                       class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
test_datagenerator = ImageDataGenerator(rescale = 1./255)

# %%
test_set = test_datagenerator.flow_from_directory('dataset/test_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
from tensorflow.keras import layers, models

# %%
cnn = models.Sequential([
    layers.Input(shape=[64, 64, 3]),
    layers.Conv2D(filters=32, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=2, strides=2),
    layers.Conv2D(filters=32, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=2, strides=2),
    layers.Flatten(),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=1, activation='sigmoid')
])

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics= ['accuracy'])

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.5826 - loss: 0.6687 - val_accuracy: 0.6700 - val_loss: 0.5998
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 62s 246ms/step - accuracy: 0.6787 - loss: 0.5973 - val_accuracy: 0.6850 - val_loss: 0.5835
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 62s 249ms/step - accuracy: 0.7157 - loss: 0.5564 - val_accuracy: 0.7400 - val_loss: 0.5251
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 63s 252ms/step - accuracy: 0.7330 - loss: 0.5349 - val_accuracy: 0.7270 - val_loss: 0.5582
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 232s 931ms/step - accuracy: 0.7506 - loss: 0.5094 - val_accuracy: 0.7460 - val_loss: 0.5222
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 72s 286ms/step - accuracy: 0.7569 - loss: 0.4929 - val_accuracy: 0.7680 - val_loss: 0.4897
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 78s 313ms/step - accuracy: 0.7649 - loss: 0.4764 - val_accuracy: 0.7530 - val_loss: 0.5242
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 78s 295ms/step - accuracy: 0.7742 - loss: 0.4680 - val_accuracy: 0.7840 - val_loss: 0.4670
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 62s 246ms/step - accuracy: 0.7771 - loss: 0.4571 - val_accuracy: 0.7905 - val_loss: 0.4631
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 244ms/step - accuracy: 0.7916 - loss: 0.4407 - val_accuracy: 0.7905 - val_loss: 0.4591
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 242ms/step - accuracy: 0.7941 - loss: 0.4451 - val_accuracy: 0.7920 - val_loss: 0.4503
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 63s 250ms/step - accuracy: 0.8043 - loss: 0.4252 - val_accuracy: 0.7960 - val_loss: 0.4547
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 64s 257ms/step - accuracy: 0.7993 - loss: 0.4242 - val_accuracy: 0.7890 - val_loss: 0.4620
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 79s 244ms/step - accuracy: 0.8104 - loss: 0.4141 - val_accuracy: 0.7995 - val_loss: 0.4384
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 240ms/step - accuracy: 0.8138 - loss: 0.4062 - val_accuracy: 0.7885 - val_loss: 0.4837
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 66s 266ms/step - accuracy: 0.8164 - loss: 0.4059 - val_accuracy: 0.7960 - val_loss: 0.4439
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 244ms/step - accuracy: 0.8142 - loss: 0.3962 - val_accuracy: 0.7815 - val_loss: 0.5193
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 59s 237ms/step - accuracy: 0.8213 - loss: 0.3909 - val_accuracy: 0.8140 - val_loss: 0.4272
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 244ms/step - accuracy: 0.8295 - loss: 0.3837 - val_accuracy: 0.8050 - val_loss: 0.4461
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 62s 246ms/step - accuracy: 0.8322 - loss: 0.3745 - val_accuracy: 0.7825 - val_loss: 0.5215
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 240ms/step - accuracy: 0.8267 - loss: 0.3788 - val_accuracy: 0.8215 - val_loss: 0.4230
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 59s 235ms/step - accuracy: 0.8320 - loss: 0.3708 - val_accuracy: 0.8220 - val_loss: 0.4172
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 59s 234ms/step - accuracy: 0.8369 - loss: 0.3654 - val_accuracy: 0.8165 - val_loss: 0.4240
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 62s 246ms/step - accuracy: 0.8382 - loss: 0.3571 - val_accuracy: 0.8120 - val_loss: 0.4575
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 63s 253ms/step - accuracy: 0.8382 - loss: 0.3547 - val_accuracy: 0.8170 - val_loss: 0.4354

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/dog.4014.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
print(prediction)
# Out:
# dog
